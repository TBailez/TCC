# %%
options = webdriver.ChromeOptions()
options.binary_location = r"C:\Program Files\Google\Chrome\Application\chrome.exe"
chrome_driver_binary = r"C:\Users\tomas\OneDrive\Área de Trabalho\Tomás\Programação\chromedriver.exe"

browser = webdriver.Chrome(chrome_driver_binary, options = options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-b29be366a165> in <module>
#       3 chrome_driver_binary = r"C:\Users\tomas\OneDrive\Área de Trabalho\Tomás\Programação\chromedriver.exe"
#       4
# ----> 5 browser = webdriver.Chrome(chrome_driver_binary, options = options)
#
# TypeError: __init__() got multiple values for argument 'options'

# %%
options

# %%
# !pip install selenium
import selenium 

# Generated by Selenium IDE
import pytest
import time
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import pandas as pd

class TestTesteedre():
  def setup_method(self, method):
    self.driver = webdriver.Chrome()
    self.vars = {}
  
  def teardown_method(self, method):
    self.driver.quit()
  
  def test_testeedre(self, empresa, periodo):
    # Test name: testee_dre
    # Step # | name | target | value
    # 1 | open | /menuestatistica/ses/balanco.aspx?tipo=seg&id=14 | 
    self.driver.get("https://www2.susep.gov.br/menuestatistica/ses/balanco.aspx?tipo=seg&id=14")

    # 3 | addSelection | id=ctl00_ContentPlaceHolder1_edEmpresas | label=04383 - 180 SEGUROS S.A.
    dropdown = self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edEmpresas")
    dropdown.find_element(By.XPATH, contains(empresa)).click()
    # 4 | click | id=ctl00_ContentPlaceHolder1_edDemonstracao | 
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edDemonstracao").click()
    # 5 | select | id=ctl00_ContentPlaceHolder1_edDemonstracao | label=DEMONSTRAÇÃO DO RESULTADO DO EXERCÍCIO - DRE
    dropdown = self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edDemonstracao")
    dropdown.find_element(By.XPATH, "//option[. = 'DEMONSTRAÇÃO DO RESULTADO DO EXERCÍCIO - DRE']").click()
    # 6 | click | id=ctl00_ContentPlaceHolder1_edMes | 
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edMes").click()
    # 7 | type | id=ctl00_ContentPlaceHolder1_edMes | 202212
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edMes").send_keys(periodo)
    # 8 | click | id=ctl00_ContentPlaceHolder1_Button1 | 

    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_Button1").click()
    # 10 | close |  | 
    self.driver.close()


#"//option[. = '04383 - 180 SEGUROS S.A.']"
#"202212"

# %%
def test_testeedre(self, empresa, periodo):
    # Test name: testee_dre
    # Step # | name | target | value
    # 1 | open | /menuestatistica/ses/balanco.aspx?tipo=seg&id=14 | 
    self.driver.get("https://www2.susep.gov.br/menuestatistica/ses/balanco.aspx?tipo=seg&id=14")

    # 3 | addSelection | id=ctl00_ContentPlaceHolder1_edEmpresas | label=04383 - 180 SEGUROS S.A.
    dropdown = self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edEmpresas")
    dropdown.find_element(By.XPATH, contains(empresa)).click()
    # 4 | click | id=ctl00_ContentPlaceHolder1_edDemonstracao | 
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edDemonstracao").click()
    # 5 | select | id=ctl00_ContentPlaceHolder1_edDemonstracao | label=DEMONSTRAÇÃO DO RESULTADO DO EXERCÍCIO - DRE
    dropdown = self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edDemonstracao")
    dropdown.find_element(By.XPATH, "//option[. = 'DEMONSTRAÇÃO DO RESULTADO DO EXERCÍCIO - DRE']").click()
    # 6 | click | id=ctl00_ContentPlaceHolder1_edMes | 
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edMes").click()
    # 7 | type | id=ctl00_ContentPlaceHolder1_edMes | 202212
    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_edMes").send_keys(periodo)
    # 8 | click | id=ctl00_ContentPlaceHolder1_Button1 | 

    self.driver.find_element(By.ID, "ctl00_ContentPlaceHolder1_Button1").click()
    # 10 | close |  | 
    self.driver.close()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SELENIUM'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-afb7012e1a2d> in <module>
#       1 import pandas as pd
# ...

# %%
df = pd.read_excel('Acompanhamento.xlsx', sheet_name='Planilha2')
lista_cod = df['SELENIUM'].to_list()
print(lista_cod)
# Out:
# ["//option[. = '06211 - ALIANÇA DO BRASIL SEGUROS S.A ']", "//option[. = '05533 - ATLÂNTICA COMPANHIA DE SEGUROS ']", "//option[. = '05312 - BRADESCO AUTO/RE COMPANHIA DE SEGUROS ']", "//option[. = '05444 - BRADESCO SEGUROS S.A ']", "//option[. = '06866 - BRADESCO VIDA E PREVIDÊNCIA S.A. ']", "//option[. = '04707 - BRASILPREV SEGUROS E PREVIDÊNCIA S/A(dados a partir de Junho/2002) ']", "//option[. = '06785 - BRASILSEG COMPANHIA DE SEGUROS ']", "//option[. = '05631 - CAIXA SEGURADORA S.A. ']", "//option[. = '08141 - CAIXA VIDA E PREVIDÊNCIA S.A. ']", "//option[. = '05193 - COMPANHIA DE SEGUROS PREVIDÊNCIA DO SUL - PREVISUL ']", "//option[. = '05321 - ITAU SEGUROS S.A. ']", "//option[. = '05096 - ITAÚ VIDA E PREVIDÊNCIA S/A ']", "//option[. = '06912 - ITAUSEG SEGURADORA S.A. ']", "//option[. = '06653 - TOO SEGUROS S.A. ']", "//option[. = '04421 - XS2 VIDA E PREVIDÊNCIA S.A. ']", "//option[. = '03476 - XS3 SEGUROS S.A. ']", "//option[. = '01121 - YOUSE SEGURADORA S.A. ']", "//option[. =
# ...

# %%
test_testeedre(self, "//option[. = '06211 - ALIANÇA DO BRASIL SEGUROS S.A ']", "202212")
